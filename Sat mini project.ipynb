# %% [markdown]
# # Project Title: Top 20 property in Butterworth, max $400K
#
# Author: Chin Wei, Cheong
#
# Date: 2 May 2020
#
# Purpose: Guideline for consumers with max target $400K. What type of property they can get at Butterworth.
# Methodology: Find out the distribution of house type  and price range in Butterworth, max 400K. Get the top 20
#              and review on argent comments.
# Findings:
# Recommendation/Conclusion:

# %% [markdown]
# Location: https://www.propertyguru.com.my/property-for-sale?region_code=MY07&area_code%5B%5D=PG02505&area_code%5B%5D=PG02503&area_code%5B%5D=PG02502&area_code%5B%5D=PG02504&area_code%5B%5D=PG02501&area_code%5B%5D=PG02599&district_code=PG025&market=residential&maxprice=400000&newProject=all

# %%
##There are JavaScript so use Selenium
## Use Selenium Webdriver to run the Javascript within the webdriver and then scrape the HTML output.

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time 
import pandas as pd
import numpy as np
import matplotlib
import plotly.express as px

driver = webdriver.Chrome('./bin/chromedriver')

url='https://www.propertyguru.com.my/property-for-sale?region_code=MY07&area_code%5B%5D=PG02505&area_code%5B%5D=PG02503&area_code%5B%5D=PG02502&area_code%5B%5D=PG02504&area_code%5B%5D=PG02501&area_code%5B%5D=PG02599&district_code=PG025&market=residential&maxprice=400000&newProject=all'

# get the data
driver.get(url)

# %%
# get the data
driver.get(url)

# %%
# load data into bs4
soup = BeautifulSoup(driver.page_source,'html.parser')

soup  ##save this page
# Out:
# <html class="listing js flexbox flexboxlegacy canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths passiveeventlisteners" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" style=""><head><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" crossorigin="anonymous" src=""></script><script async="" src="//survey.survicate.com/workspaces/uGOUBOERQlLVnfJERggWoBHNZMoSoybS/web_surveys.js"></script><script async="" src="https://sb.scorecardresearch.com/c2/13151479/cs.js" type="text/javascript"></script><script async="" src="h
# ...

# %%
print(soup.prettify()) ## Observe that the downloaded page
# Out:
# <html class="listing js flexbox flexboxlegacy canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths passiveeventlisteners" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" style="">
#  <head>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" crossorigin="anonymous" src="">
#   </script>
#   <script async="" src="//survey.survicate.com/workspaces/uGOUBOERQlLVnfJERggWoBHNZMoSoybS/web_surveys.js">
#   </script>
# ...

# %%
list(soup.children) ## Observe that the HTML doc is now a human readable document
# Out:
# [<html class="listing js flexbox flexboxlegacy canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths passiveeventlisteners" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" style=""><head><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" crossorigin="anonymous" src=""></script><script async="" src="//survey.survicate.com/workspaces/uGOUBOERQlLVnfJERggWoBHNZMoSoybS/web_surveys.js"></script><script async="" src="https://sb.scorecardresearch.com/c2/13151479/cs.js" type="text/javascript"></script><script async="" src="
# ...

# %%
print(len(div.text)) # total items in the list
# Out:
# 7602

# %%
print(soup_div[:20]) # print just only the first 20 items in the list
# Out:
# [<div id="users-web-container">
# <script type="text/javascript">window.USERS_WEB_HOST = "https://users-web.propertyguru.com";</script>
# <script src="https://users-web.propertyguru.com/vendor~app~lsp.b80020073c1bd9120b4a.js" type="text/javascript"></script><script src="https://users-web.propertyguru.com/app.ef7a7e90dcc528205112.js" type="text/javascript"></script>
# </div>, <div id="wrapper-outer">
# <div id="wrapper">
# <div id="wrapper-inner">
# <!--// Header //-->
# <div class="alert alert-warning" id="gdpr-alert" role="alert">
#                 To comply with GDPR we will not store any personally identifiable information from you. Therefore we will serve sub-optimal experience where some features such as Login/Signup are disabled. However, you will be able to search and see all the properties, see agent contact details and contact them offline on your own.
#             </div>
# <div class="accept-cookies hidden-xs hidden-sm">
# <div class="container">
# ...

# %%
data=[]
# get data simply by looking for each a links
for div in soup.find_all('div',attrs={'class':'listing-widget-new'}):
    data.append(div.text)
    
data
# Out:
# ['\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                  11 \n\n\n\n\n\nPangsapuri Sri Chempa\nLorong Widuri 1 Off Jalan Raja Uda, Butterworth, Raja Uda, Butterworth, Penang\n\n\n\nRM 308,000 \n\n\n3  2 \n958 sqftRM\xa0321.50\xa0psf\n\n\nApartment\nFreehold\nBuilt: 2013\n\n2d\n\n\n\n\n\n\n\nListed by Daniel Pang Wee Han\n"Corner Unit"\n\n\n\n\n\n\n\nWhatsApp\n\n\n\n\n\nCall\n\n\n\n\n\n+60 16 348 4319\n\nCall\n\n\n\n\n\n\n\nShortlist\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                  33 \n\n\n\n\n\nTelaga Emas Apartment\nJalan Telaga Air off Lebuhraya Lingkaran Luar Butterworth, Butterworth, Penang\n\n\n\nRM 390,000 \n\n\n2  2 \n1330 sqftRM\xa0293.23\xa0psf\n\n\nApartment\nFreehold\n\n1w\n\n\n\n\n\n\n\nListed by Joanne Lim\n"Nice Renovation And Partially Furnished"\n\n\n\n\n\n\n\nWhatsApp\n\n\n\n\n\nCall\n\n\n\n\n\n+60 16 260 5616\n\nCall\n\n\n\n\n\n\n\nShortlist\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                  19 \n\n\n\n\n\nSea View Tower @ Harbour Place\nJalan Harbou
# ...

# %%
import pandas as pd

names = []
pricesqfts = []
agent_names = []
comments = []

df = pd.DataFrame(columns=['names','pricesqfts','agent_names', 'comments'])

soup_list = soup.findAll('div', attrs={'class':'listing-widget-new'})

for item in range(len(soup_list)):
    
    # Get Name
    name = soup_list[item].findAll("a",attrs={"itemprop":"url"})
    for items in range(len(name)):
#         print(name[items].text)   
        names.append(name[items].text)
    
    # Get Price
    price_listings = soup_list[item].findAll("li", attrs={"class":"listing-floorarea"})

    for items in range(len(price_listings)):
#         print(items, price_listings[items].text)
        pricesqfts.append(price_listings[items].text)
    
    # Get Agent Name and Comments
    listings = soup_list[item].findAll("div", attrs={"class":"headline"})
        
    for items in range(len(listings)):
        agent_name = listings[items].find("div", attrs={"class":"agent-name"}).text
        comment = listings[items].find("div", attrs={"class":"agent-name"}).find_next_sibling("div")
        agent_names.append(agent_name)
        comments.append(comment)

# %%
names
# Out:
# ['Pangsapuri Sri Chempa',
#  'Telaga Emas Apartment',
#  'Sea View Tower @ Harbour Place',
#  'Ocean View Residences @ Harbour Place',
#  'Park View Tower @ Harbour Place',
#  'Wellesley Residences @ Harbour Place',
#  'Park View Tower @ Harbour Place',
#  'Pangsapuri Ria Apartment C (Ruby Tower)',
#  'Pangsapuri Ria Apartment C (Ruby Tower)',
#  'Cassia Resort Condominium',
#  'Pangsapuri Seri cantik, Raja Uda',
#  'Ocean View Residences @ Harbour Place',
#  'Park View Tower @ Harbour Place',
#  'Woodsbury Suites @ Harbour Place',
#  'Bertam Hulubalang 3',
#  'Perai Condo (Can Full Loan, 0 down payment)',
#  'Citrine Tower (Ria Apartment Block D) Butterworth',
#  'Pangsapuri Ria Apartment C (Ruby Tower)',
#  'Ocean View Residences @ Harbour Place',
#  'Seaview Tower Condo']

# %%
pricesqfts
# Out:
# ['958 sqft',
#  'RM\xa0321.50\xa0psf',
#  '1330 sqft',
#  'RM\xa0293.23\xa0psf',
#  '998 sqft',
#  'RM\xa0380.76\xa0psf',
#  '938 sqft',
#  'RM\xa0413.65\xa0psf',
#  '883 sqft',
#  'RM\xa0326.16\xa0psf',
#  '650 sqft',
#  'RM\xa0461.54\xa0psf',
#  '883 sqft',
#  'RM\xa0322.76\xa0psf',
#  '780 sqft',
#  'RM\xa0358.97\xa0psf',
#  '780 sqft',
#  'RM\xa0333.33\xa0psf',
#  '1138 sqft',
#  'RM\xa0349.74\xa0psf',
#  '1104 sqft',
#  'RM\xa0353.26\xa0psf',
#  '938 sqft',
#  'RM\xa0413.65\xa0psf',
#  '883 sqft',
#  'RM\xa0326.16\xa0psf',
#  '750 sqft',
#  'RM\xa0506.67\xa0psf',
#  '1550 sqft',
#  'RM\xa0129.03\xa0psf',
#  '990 sqft',
#  'RM\xa0353.54\xa0psf',
#  '1000 sqft',
#  'RM\xa0320.00\xa0psf',
#  '780 sqft',
#  'RM\xa0269.23\xa0psf',
#  '938 sqft',
#  'RM\xa0408.32\xa0psf',
#  '670 sqft',
#  'RM\xa0446.27\xa0psf']

# %%
agent_names
# Out:
# ['Listed by Daniel Pang Wee Han',
#  'Listed by Joanne Lim',
#  'Listed by SP Whong',
#  'Listed by C L Chia',
#  'Listed by May Tan',
#  'Listed by Serene Ng',
#  'Listed by Serene Ng',
#  'Listed by May Tan',
#  'Listed by May Tan',
#  'Listed by May Tan',
#  'Listed by Serene Ng',
#  'Listed by Serene Ng',
#  'Listed by Philip Ong',
#  'Listed by Philip Ong',
#  'Listed by SP Whong',
#  'Listed by Lissa Ooi',
#  'Listed by Yzan Cheng',
#  'Listed by Yzan Cheng',
#  'Listed by SP Whong',
#  'Listed by Adilawati Sobri']

# %%
comments
# Out:
# [<div>"Corner Unit"</div>,
#  <div>"Nice Renovation And Partially Furnished"</div>,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
import pandas as pd

names = []
pricesqfts = []
agent_names = []
comments = []

df = pd.DataFrame(columns=['Agent_names','Categories','Price', 'Review'])
soup_list = soup.findAll('div', attrs={'class':'listing-widget-new'})

for item in range(len(soup_list)):
    
    # Get Name
    name = soup_list[item].findAll("a",attrs={"itemprop":"url"})
    for items in range(len(name)): 
        names.append(name[items].text)
    
    # Get Price
    price_listings = soup_list[item].findAll("li", attrs={"class":"listing-floorarea"})

    for items in range(len(price_listings)):
        pricesqfts.append(price_listings[items].text)
    
    # Get Agent Name and Comments
    listings = soup_list[item].findAll("div", attrs={"class":"headline"})
        
    for items in range(len(listings)):
        agent_name = listings[items].find("div", attrs={"class":"agent-name"}).text
        comment = listings[items].find("div", attrs={"class":"agent-name"}).find_next_sibling("div")
        agent_names.append(agent_name)
        comments.append(comment)
        

df = df.append({'Agent_names': agent_name, 'Categories':name , 'Price':pricesqfts, 'Review': comment}, ignore_index=True)
    
df
# Out:
#                  Agent_names  \
# 0  Listed by Adilawati Sobri
#
#                                           Categories  \
# 0  [[Pangsapuri Sri Chempa], [Telaga Emas Apartme...
#
#                                                Price Review
# 0  [958 sqft, RM 321.50 psf, 1330 sqft, RM 293.23...   None

# %%
##Word cloud from a Pandas data frame

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = data.Tweet.values
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
import pandas as pd

names = []
pricesqfts = []
agent_names = []
comments = []

df = pd.DataFrame(columns=['Agent_names','Categories','Price', 'Review'])
soup_list = soup.findAll('div', attrs={'class':'listing-widget-new'})

for item in range(len(soup_list)):
    
    # Get Name
    name = soup_list[item].findAll("a",attrs={"itemprop":"url"})
    for items in range(len(name)): 
        names.append(name[items].text)
    
    # Get Price
    price_listings = soup_list[item].findAll("li", attrs={"class":"listing-floorarea"})

    for items in range(len(price_listings)):
        pricesqfts.append(price_listings[items].text)
    
    # Get Agent Name and Comments
    listings = soup_list[item].findAll("div", attrs={"class":"headline"})
        
    for items in range(len(listings)):
        agent_name = listings[items].find("div", attrs={"class":"agent-name"}).text
        comment = listings[items].find("div", attrs={"class":"agent-name"}).find_next_sibling("div")
        agent_names.append(agent_name)
        comments.append(comment)
        

df = df.append({'Agent_names': agent_name, 'Categories':name , 'Price':pricesqfts, 'Review': comment}, ignore_index=True)
    
df

# %%
def getAndParseURL(url):
    browser.get(url)
    code = browser.page_source
    soup = BeautifulSoup(code,'html.parser')
    return(soup)
